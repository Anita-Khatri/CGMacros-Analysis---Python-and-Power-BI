# %%
import pandas as pd
df = pd.read_csv("gut_health_test.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47 entries, 0 to 46
# Data columns (total 23 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   subject                                      47 non-null     int64
#  1   Gut Lining Health                            42 non-null     float64
#  2   LPS Biosynthesis Pathways                    42 non-null     float64
#  3   Biofilm, Chemotaxis, and Virulence Pathways  42 non-null     float64
#  4   TMA Production Pathways                      42 non-null     float64
#  5   Ammonia Production Pathways                  42 non-null     float64
#  6   Metabolic Fitness                            42 non-null     float64
#  7   Active Microbial Diversity                   42 non-null     float64
#  8   Butyrate Production Pathways                 42 non-null     float64
# ...

# %%
import pandas as pd

# Read the CSV file
df = pd.read_csv('gut_health_test.csv')

# Define the mapping
value_map = {
    1: 'Not Optimal',
    2: 'Average',
    3: 'Good'
}

# List of columns you want to update (example)
columns_to_update = ['Gut Lining Health', 'LPS Biosynthesis Pathways', 'Biofilm, Chemotaxis, and Virulence Pathways', 'TMA Production Pathways', 'Ammonia Production Pathways', 'Metabolic Fitness', 'Active Microbial Diversity', 'Butyrate Production Pathways', 'Flagellar Assembly Pathways', 'Putrescine Production Pathways', 'Uric Acid Production Pathways', 'Bile Acid Metabolism Pathways', 'Inflammatory Activity', 'Gut Microbiome Health', 'Digestive Efficiency', 'Protein Fermentation', 'Gas Production', 'Methane Gas Production Pathways', 'Sulfide Gas Production Pathways', 'Oxalate Metabolism Pathways', 'Salt Stress Pathways', 'Microbiome-Induced Stress']  
# Apply the mapping to each column
for col in columns_to_update:
    if col in df.columns:
        df[col] = df[col].map(value_map)

# Save the updated DataFrame back to the same file
df.to_csv('gut_health_test.csv', index=False)

print("Values in selected columns replaced successfully.")
# Out:
# Values in selected columns replaced successfully.

# %%
df.head(10)
# Out:
#    subject Gut Lining Health LPS Biosynthesis Pathways  \
# 0        1           Average                   Average
# 1        2       Not Optimal               Not Optimal
# 2        3           Average               Not Optimal
# 3        4       Not Optimal               Not Optimal
# 4        5       Not Optimal               Not Optimal
# 5        6       Not Optimal               Not Optimal
# 6        7           Average               Not Optimal
# 7        8           Average               Not Optimal
# 8        9           Average               Not Optimal
# 9       10           Average               Not Optimal
#
#   Biofilm, Chemotaxis, and Virulence Pathways TMA Production Pathways  \
# 0                                 Not Optimal                 Average
# 1                                 Not Optimal                 Average
# 2                                 Not Optimal                 Average
# 3                                 Not Optimal             Not Optimal
# ...

# %%
df = pd.read_csv("gut_health_test_cleaned.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47 entries, 0 to 46
# Data columns (total 23 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   subject                                      47 non-null     int64
#  1   Gut Lining Health                            42 non-null     object
#  2   LPS Biosynthesis Pathways                    42 non-null     object
#  3   Biofilm, Chemotaxis, and Virulence Pathways  42 non-null     object
#  4   TMA Production Pathways                      42 non-null     object
#  5   Ammonia Production Pathways                  42 non-null     object
#  6   Metabolic Fitness                            42 non-null     object
#  7   Active Microbial Diversity                   42 non-null     object
#  8   Butyrate Production Pathways                 42 non-null     object
# ...

# %%
# Read the CSV file and explicitly set all column dtypes to string
# Use 'object' or 'string' for general string type.
# 'string' (Pandas StringDtype) is generally preferred for modern Pandas.
import pandas as pd
#df = pd.read_csv("gut_health_test.csv")
#df.info()
df = pd.read_csv("gut_health_test_cleaned.csv", dtype=str) # Or dtype='string'

print("DataFrame after reading with all columns as strings:")
print(df.head()) # Display first few rows
print("\nData Types after initial read:")
print(df.dtypes) # Show data types of all columns
# Out:
# DataFrame after reading with all columns as strings:
#   subject Gut Lining Health LPS Biosynthesis Pathways  \
# 0       1           Average                   Average
# 1       2       Not Optimal               Not Optimal
# 2       3           Average               Not Optimal
# 3       4       Not Optimal               Not Optimal
# 4       5       Not Optimal               Not Optimal
#
#   Biofilm, Chemotaxis, and Virulence Pathways TMA Production Pathways  \
# 0                                 Not Optimal                 Average
# 1                                 Not Optimal                 Average
# 2                                 Not Optimal                 Average
# 3                                 Not Optimal             Not Optimal
# 4                                     Average                    Good
#
#   Ammonia Production Pathways Metabolic Fitness Active Microbial Diversity  \
# 0                 Not Optimal              Good                    Average
# ...

# %%
df = pd.read_csv('gut_health_test_cleaned.csv')

print("Original DataFrame:")
print(df)
print("\nOriginal Data Types:")
print(df.dtypes)

# Convert the 'subject' column from string to integer
df['subject'] = df['subject'].astype(int)

print("\nDataFrame after converting 'subject' to int:")
print(df)
print("\nNew Data Types:")
print(df.dtypes)
# Out:
# Original DataFrame:
#     subject Gut Lining Health LPS Biosynthesis Pathways  \
# 0         1           Average                   Average
# 1         2       Not Optimal               Not Optimal
# 2         3           Average               Not Optimal
# 3         4       Not Optimal               Not Optimal
# 4         5       Not Optimal               Not Optimal
# 5         6       Not Optimal               Not Optimal
# 6         7           Average               Not Optimal
# 7         8           Average               Not Optimal
# 8         9           Average               Not Optimal
# 9        10           Average               Not Optimal
# 10       11       Not Optimal               Not Optimal
# 11       12           Average               Not Optimal
# 12       13       Not Optimal                   Average
# 13       14           Average                   Average
# 14       15              Good               Not Optimal
# ...

# %%
import pandas as pd
df = pd.read_csv('gut_health_test_cleaned.csv')
df_cleaned = df[~df['subject'].isin([24, 25])]
print(df_cleaned.head(30))
df_cleaned.to_csv('gut_health_test_final_cleaned.csv', index=False)
# Out:
#     subject Gut Lining Health LPS Biosynthesis Pathways  \
# 0         1           Average                   Average
# 1         2       Not Optimal               Not Optimal
# 2         3           Average               Not Optimal
# 3         4       Not Optimal               Not Optimal
# 4         5       Not Optimal               Not Optimal
# 5         6       Not Optimal               Not Optimal
# 6         7           Average               Not Optimal
# 7         8           Average               Not Optimal
# 8         9           Average               Not Optimal
# 9        10           Average               Not Optimal
# 10       11       Not Optimal               Not Optimal
# 11       12           Average               Not Optimal
# 12       13       Not Optimal                   Average
# 13       14           Average                   Average
# 14       15              Good               Not Optimal
# 15       16           Average                   Average
# ...
