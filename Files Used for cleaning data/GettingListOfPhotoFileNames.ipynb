# %%
import os
import pandas as pd

# Set your folder path
photo_folder = "CGMacros_Subjects_Photos_folder"  # 🔁 Replace with your actual folder path

# List of common photo file extensions
photo_extensions = ('.jpg', '.jpeg', '.png', '.bmp', '.tiff', '.gif', '.webp')

# Get only photo files
photo_files = [f for f in os.listdir(photo_folder) if f.lower().endswith(photo_extensions)]

# Print the list
#print("📸 Photo Files:")
#for photo in photo_files:
    #print(photo)

# Optionally: Save to a text file or CSV
#with open("photo_file_list.txt", "w") as file:
    #for photo in photo_files:
        #file.write(photo + "\n")

pd.DataFrame(photo_files, columns=["filename"]).to_csv("photo_files.csv", index=False)

# %%
#getting the list of suject 1 photos file names.
import os
import pandas as pd

# Set the folder path
photo_folder = "Subject1PhotosCGMacros"  

# List of common photo file extensions
photo_extensions = ('.jpg', '.jpeg', '.png', '.bmp', '.tiff', '.gif', '.webp')

# Get only photo files
photo_files = [f for f in os.listdir(photo_folder) if f.lower().endswith(photo_extensions)]

pd.DataFrame(photo_files, columns=["filename"]).to_csv("Subject_1_photo_files_names.csv", index=False)

# %%
#getting the list of suject 2 photos file names.
import os
import pandas as pd

# Set the folder path
photo_folder = "Subject2PhotosCGMacros" 

# List of common photo file extensions
photo_extensions = ('.jpg', '.jpeg', '.png', '.bmp', '.tiff', '.gif', '.webp')

# Get only photo files
photo_files = [f for f in os.listdir(photo_folder) if f.lower().endswith(photo_extensions)]


pd.DataFrame(photo_files, columns=["filename"]).to_csv("Subject_2_photo_files_names.csv", index=False)

# %%
#getting the list of suject 3 photos file names.
import os
import pandas as pd

# Set the folder path
photo_folder = "Subject3PhotosCGMacros" 

# List of common photo file extensions
photo_extensions = ('.jpg', '.jpeg', '.png', '.bmp', '.tiff', '.gif', '.webp')

# Get only photo files
photo_files = [f for f in os.listdir(photo_folder) if f.lower().endswith(photo_extensions)]


pd.DataFrame(photo_files, columns=["filename"]).to_csv("Subject_3_photo_files_names.csv", index=False)

# %%
#getting the list of suject 4 photos file names.
import os
import pandas as pd

# Set the folder path
photo_folder = "subject4PhotosCGMacros" 

# List of common photo file extensions
photo_extensions = ('.jpg', '.jpeg', '.png', '.bmp', '.tiff', '.gif', '.webp')

# Get only photo files
photo_files = [f for f in os.listdir(photo_folder) if f.lower().endswith(photo_extensions)]


pd.DataFrame(photo_files, columns=["filename"]).to_csv("Subject_4_photo_files_names.csv", index=False)

# %%
#getting the list of suject 5 photos file names.
import os
import pandas as pd

# Set the folder path
photo_folder = "Subject5PhotosCGMacros" 

# List of common photo file extensions
photo_extensions = ('.jpg', '.jpeg', '.png', '.bmp', '.tiff', '.gif', '.webp')

# Get only photo files
photo_files = [f for f in os.listdir(photo_folder) if f.lower().endswith(photo_extensions)]


pd.DataFrame(photo_files, columns=["filename"]).to_csv("Subject_5_photo_files_names.csv", index=False)

# %%
#getting the list of suject 6 photos file names.
import os
import pandas as pd

# Set the folder path
photo_folder = "Subject6PhotosCGMacros" 

# List of common photo file extensions
photo_extensions = ('.jpg', '.jpeg', '.png', '.bmp', '.tiff', '.gif', '.webp')

# Get only photo files
photo_files = [f for f in os.listdir(photo_folder) if f.lower().endswith(photo_extensions)]


pd.DataFrame(photo_files, columns=["filename"]).to_csv("Subject_6_photo_files_names.csv", index=False)

# %%
#getting the list of suject 7 photos file names.
import os
import pandas as pd

# Set the folder path
photo_folder = "Subject7PhotosCGMacros" 

# List of common photo file extensions
photo_extensions = ('.jpg', '.jpeg', '.png', '.bmp', '.tiff', '.gif', '.webp')

# Get only photo files
photo_files = [f for f in os.listdir(photo_folder) if f.lower().endswith(photo_extensions)]


pd.DataFrame(photo_files, columns=["filename"]).to_csv("Subject_7_photo_files_names.csv", index=False)

# %%
#getting the list of suject 8 photos file names.
import os
import pandas as pd

# Set the folder path
photo_folder = "Subject8PhotosCGMacros" 

# List of common photo file extensions
photo_extensions = ('.jpg', '.jpeg', '.png', '.bmp', '.tiff', '.gif', '.webp')

# Get only photo files
photo_files = [f for f in os.listdir(photo_folder) if f.lower().endswith(photo_extensions)]


pd.DataFrame(photo_files, columns=["filename"]).to_csv("Subject_8_photo_files_names.csv", index=False)

# %%
#getting the list of suject 9 photos file names.
import os
import pandas as pd

# Set the folder path
photo_folder = "Subject9PhotosCGMacros" 

# List of common photo file extensions
photo_extensions = ('.jpg', '.jpeg', '.png', '.bmp', '.tiff', '.gif', '.webp')

# Get only photo files
photo_files = [f for f in os.listdir(photo_folder) if f.lower().endswith(photo_extensions)]


pd.DataFrame(photo_files, columns=["filename"]).to_csv("Subject_9_photo_files_names.csv", index=False)

# %%
#getting the list of suject 10 photos file names.
import os
import pandas as pd

# Set the folder path
photo_folder = "Subject10PhotosCGMacros" 

# List of common photo file extensions
photo_extensions = ('.jpg', '.jpeg', '.png', '.bmp', '.tiff', '.gif', '.webp')

# Get only photo files
photo_files = [f for f in os.listdir(photo_folder) if f.lower().endswith(photo_extensions)]


pd.DataFrame(photo_files, columns=["filename"]).to_csv("Subject_10_photo_files_names.csv", index=False)

# %%
#getting the list of suject 11 photos file names.
import os
import pandas as pd

# Set the folder path
photo_folder = "Subject11PhotosCGMacros" 

# List of common photo file extensions
photo_extensions = ('.jpg', '.jpeg', '.png', '.bmp', '.tiff', '.gif', '.webp')

# Get only photo files
photo_files = [f for f in os.listdir(photo_folder) if f.lower().endswith(photo_extensions)]


pd.DataFrame(photo_files, columns=["filename"]).to_csv("Subject_11_photo_files_names.csv", index=False)

# %%
#getting the list of suject 12 photos file names.
import os
import pandas as pd

# Set the folder path
photo_folder = "Subject12PhotosCGMacros" 

# List of common photo file extensions
photo_extensions = ('.jpg', '.jpeg', '.png', '.bmp', '.tiff', '.gif', '.webp')

# Get only photo files
photo_files = [f for f in os.listdir(photo_folder) if f.lower().endswith(photo_extensions)]


pd.DataFrame(photo_files, columns=["filename"]).to_csv("Subject_12_photo_files_names.csv", index=False)

# %%
#getting the list of suject 13 photos file names.
import os
import pandas as pd

# Set the folder path
photo_folder = "Subject13PhotosCGMacros" 

# List of common photo file extensions
photo_extensions = ('.jpg', '.jpeg', '.png', '.bmp', '.tiff', '.gif', '.webp')

# Get only photo files
photo_files = [f for f in os.listdir(photo_folder) if f.lower().endswith(photo_extensions)]


pd.DataFrame(photo_files, columns=["filename"]).to_csv("Subject_13_photo_files_names.csv", index=False)

# %%
#getting the list of suject 14 photos file names.
import os
import pandas as pd

# Set the folder path
photo_folder = "Subject14PhotosCGMacros" 

# List of common photo file extensions
photo_extensions = ('.jpg', '.jpeg', '.png', '.bmp', '.tiff', '.gif', '.webp')

# Get only photo files
photo_files = [f for f in os.listdir(photo_folder) if f.lower().endswith(photo_extensions)]


pd.DataFrame(photo_files, columns=["filename"]).to_csv("Subject_14_photo_files_names.csv", index=False)

# %%
#getting the list of suject 15 photos file names.
import os
import pandas as pd

# Set the folder path
photo_folder = "Subject15PhotosCGMacros" 

# List of common photo file extensions
photo_extensions = ('.jpg', '.jpeg', '.png', '.bmp', '.tiff', '.gif', '.webp')

# Get only photo files
photo_files = [f for f in os.listdir(photo_folder) if f.lower().endswith(photo_extensions)]


pd.DataFrame(photo_files, columns=["filename"]).to_csv("Subject_15_photo_files_names.csv", index=False)

# %%
#getting the list of suject 16 photos file names.
import os
import pandas as pd

# Set the folder path
photo_folder = "Subject16PhotosCGMacros" 

# List of common photo file extensions
photo_extensions = ('.jpg', '.jpeg', '.png', '.bmp', '.tiff', '.gif', '.webp')

# Get only photo files
photo_files = [f for f in os.listdir(photo_folder) if f.lower().endswith(photo_extensions)]


pd.DataFrame(photo_files, columns=["filename"]).to_csv("Subject_16_photo_files_names.csv", index=False)

# %%
#getting the list of suject 17 photos file names.
import os
import pandas as pd

# Set the folder path
photo_folder = "Subject17PhotosCGMacros" 

# List of common photo file extensions
photo_extensions = ('.jpg', '.jpeg', '.png', '.bmp', '.tiff', '.gif', '.webp')

# Get only photo files
photo_files = [f for f in os.listdir(photo_folder) if f.lower().endswith(photo_extensions)]


pd.DataFrame(photo_files, columns=["filename"]).to_csv("Subject_17_photo_files_names.csv", index=False)

# %%
#getting the list of suject 18 photos file names.
import os
import pandas as pd

# Set the folder path
photo_folder = "Subject18PhotosCGMacros" 

# List of common photo file extensions
photo_extensions = ('.jpg', '.jpeg', '.png', '.bmp', '.tiff', '.gif', '.webp')

# Get only photo files
photo_files = [f for f in os.listdir(photo_folder) if f.lower().endswith(photo_extensions)]


pd.DataFrame(photo_files, columns=["filename"]).to_csv("Subject_18_photo_files_names.csv", index=False)

# %%
#getting the list of suject 19 photos file names.
import os
import pandas as pd

# Set the folder path
photo_folder = "Subject19PhotosCGMacros" 

# List of common photo file extensions
photo_extensions = ('.jpg', '.jpeg', '.png', '.bmp', '.tiff', '.gif', '.webp')

# Get only photo files
photo_files = [f for f in os.listdir(photo_folder) if f.lower().endswith(photo_extensions)]


pd.DataFrame(photo_files, columns=["filename"]).to_csv("Subject_19_photo_files_names.csv", index=False)

# %%
#getting the list of suject 20 photos file names.
import os
import pandas as pd

# Set the folder path
photo_folder = "Subject20PhotosCGMacros" 

# List of common photo file extensions
photo_extensions = ('.jpg', '.jpeg', '.png', '.bmp', '.tiff', '.gif', '.webp')

# Get only photo files
photo_files = [f for f in os.listdir(photo_folder) if f.lower().endswith(photo_extensions)]


pd.DataFrame(photo_files, columns=["filename"]).to_csv("Subject_20_photo_files_names.csv", index=False)

# %%
#getting the list of suject 21 photos file names.
import os
import pandas as pd

# Set the folder path
photo_folder = "Subject21PhotosCGMacros" 

# List of common photo file extensions
photo_extensions = ('.jpg', '.jpeg', '.png', '.bmp', '.tiff', '.gif', '.webp')

# Get only photo files
photo_files = [f for f in os.listdir(photo_folder) if f.lower().endswith(photo_extensions)]


pd.DataFrame(photo_files, columns=["filename"]).to_csv("Subject_21_photo_files_names.csv", index=False)

# %%
#getting the list of suject 22 photos file names.
import os
import pandas as pd

# Set the folder path
photo_folder = "Subject22PhotosCGMacros" 

# List of common photo file extensions
photo_extensions = ('.jpg', '.jpeg', '.png', '.bmp', '.tiff', '.gif', '.webp')

# Get only photo files
photo_files = [f for f in os.listdir(photo_folder) if f.lower().endswith(photo_extensions)]


pd.DataFrame(photo_files, columns=["filename"]).to_csv("Subject_22_photo_files_names.csv", index=False)

# %%
#getting the list of suject 23 photos file names.
import os
import pandas as pd

# Set the folder path
photo_folder = "Subject23PhotosCGMacros" 

# List of common photo file extensions
photo_extensions = ('.jpg', '.jpeg', '.png', '.bmp', '.tiff', '.gif', '.webp')

# Get only photo files
photo_files = [f for f in os.listdir(photo_folder) if f.lower().endswith(photo_extensions)]


pd.DataFrame(photo_files, columns=["filename"]).to_csv("Subject_23_photo_files_names.csv", index=False)

# %%
#getting the list of suject 26 photos file names.
import os
import pandas as pd

# Set the folder path
photo_folder = "Subject26PhotosCGMacros" 

# List of common photo file extensions
photo_extensions = ('.jpg', '.jpeg', '.png', '.bmp', '.tiff', '.gif', '.webp')

# Get only photo files
photo_files = [f for f in os.listdir(photo_folder) if f.lower().endswith(photo_extensions)]


pd.DataFrame(photo_files, columns=["filename"]).to_csv("Subject_26_photo_files_names.csv", index=False)

# %%
#getting the list of suject 27 photos file names.
import os
import pandas as pd

# Set the folder path
photo_folder = "Subject27PhotosCGMacros" 

# List of common photo file extensions
photo_extensions = ('.jpg', '.jpeg', '.png', '.bmp', '.tiff', '.gif', '.webp')

# Get only photo files
photo_files = [f for f in os.listdir(photo_folder) if f.lower().endswith(photo_extensions)]


pd.DataFrame(photo_files, columns=["filename"]).to_csv("Subject_27_photo_files_names.csv", index=False)

# %%
#getting the list of suject 28 photos file names.
import os
import pandas as pd

# Set the folder path
photo_folder = "Subject28PhotosCGMacros" 

# List of common photo file extensions
photo_extensions = ('.jpg', '.jpeg', '.png', '.bmp', '.tiff', '.gif', '.webp')

# Get only photo files
photo_files = [f for f in os.listdir(photo_folder) if f.lower().endswith(photo_extensions)]


pd.DataFrame(photo_files, columns=["filename"]).to_csv("Subject_28_photo_files_names.csv", index=False)

# %%
#getting the list of suject 29 photos file names.
import os
import pandas as pd

# Set the folder path
photo_folder = "Subject29PhotosCGMacros" 

# List of common photo file extensions
photo_extensions = ('.jpg', '.jpeg', '.png', '.bmp', '.tiff', '.gif', '.webp')

# Get only photo files
photo_files = [f for f in os.listdir(photo_folder) if f.lower().endswith(photo_extensions)]


pd.DataFrame(photo_files, columns=["filename"]).to_csv("Subject_29_photo_files_names.csv", index=False)

# %%
#getting the list of suject 30 photos file names.
import os
import pandas as pd

# Set the folder path
photo_folder = "Subject30PhotosCGMacros" 

# List of common photo file extensions
photo_extensions = ('.jpg', '.jpeg', '.png', '.bmp', '.tiff', '.gif', '.webp')

# Get only photo files
photo_files = [f for f in os.listdir(photo_folder) if f.lower().endswith(photo_extensions)]


pd.DataFrame(photo_files, columns=["filename"]).to_csv("Subject_30_photo_files_names.csv", index=False)

# %%
#getting the list of suject 31 photos file names.
import os
import pandas as pd

# Set the folder path
photo_folder = "Subject31PhotosCGMacros" 

# List of common photo file extensions
photo_extensions = ('.jpg', '.jpeg', '.png', '.bmp', '.tiff', '.gif', '.webp')

# Get only photo files
photo_files = [f for f in os.listdir(photo_folder) if f.lower().endswith(photo_extensions)]


pd.DataFrame(photo_files, columns=["filename"]).to_csv("Subject_31_photo_files_names.csv", index=False)

# %%
#getting the list of suject 32 photos file names.
import os
import pandas as pd

# Set the folder path
photo_folder = "Subject32PhotosCGMacros" 

# List of common photo file extensions
photo_extensions = ('.jpg', '.jpeg', '.png', '.bmp', '.tiff', '.gif', '.webp')

# Get only photo files
photo_files = [f for f in os.listdir(photo_folder) if f.lower().endswith(photo_extensions)]


pd.DataFrame(photo_files, columns=["filename"]).to_csv("Subject_32_photo_files_names.csv", index=False)

# %%
#getting the list of suject 33 photos file names.
import os
import pandas as pd

# Set the folder path
photo_folder = "Subject33PhotosCGMacros" 

# List of common photo file extensions
photo_extensions = ('.jpg', '.jpeg', '.png', '.bmp', '.tiff', '.gif', '.webp')

# Get only photo files
photo_files = [f for f in os.listdir(photo_folder) if f.lower().endswith(photo_extensions)]


pd.DataFrame(photo_files, columns=["filename"]).to_csv("Subject_33_photo_files_names.csv", index=False)

# %%
#getting the list of suject 34 photos file names.
import os
import pandas as pd

# Set the folder path
photo_folder = "Subject34PhotosCGMacros" 

# List of common photo file extensions
photo_extensions = ('.jpg', '.jpeg', '.png', '.bmp', '.tiff', '.gif', '.webp')

# Get only photo files
photo_files = [f for f in os.listdir(photo_folder) if f.lower().endswith(photo_extensions)]


pd.DataFrame(photo_files, columns=["filename"]).to_csv("Subject_34_photo_files_names.csv", index=False)

# %%
#getting the list of suject 35 photos file names.
import os
import pandas as pd

# Set the folder path
photo_folder = "Subject35PhotosCGMacros" 

# List of common photo file extensions
photo_extensions = ('.jpg', '.jpeg', '.png', '.bmp', '.tiff', '.gif', '.webp')

# Get only photo files
photo_files = [f for f in os.listdir(photo_folder) if f.lower().endswith(photo_extensions)]


pd.DataFrame(photo_files, columns=["filename"]).to_csv("Subject_35_photo_files_names.csv", index=False)

# %%
#getting the list of suject 36 photos file names.
import os
import pandas as pd

# Set the folder path
photo_folder = "Subject36PhotosCGMacros" 

# List of common photo file extensions
photo_extensions = ('.jpg', '.jpeg', '.png', '.bmp', '.tiff', '.gif', '.webp')

# Get only photo files
photo_files = [f for f in os.listdir(photo_folder) if f.lower().endswith(photo_extensions)]


pd.DataFrame(photo_files, columns=["filename"]).to_csv("Subject_36_photo_files_names.csv", index=False)

# %%
#getting the list of suject 38 photos file names.
import os
import pandas as pd

# Set the folder path
photo_folder = "Subject38PhotosCGMacros" 

# List of common photo file extensions
photo_extensions = ('.jpg', '.jpeg', '.png', '.bmp', '.tiff', '.gif', '.webp')

# Get only photo files
photo_files = [f for f in os.listdir(photo_folder) if f.lower().endswith(photo_extensions)]


pd.DataFrame(photo_files, columns=["filename"]).to_csv("Subject_38_photo_files_names.csv", index=False)

# %%
#getting the list of suject 39 photos file names.
import os
import pandas as pd

# Set the folder path
photo_folder = "Subject39PhotosCGMacros" 

# List of common photo file extensions
photo_extensions = ('.jpg', '.jpeg', '.png', '.bmp', '.tiff', '.gif', '.webp')

# Get only photo files
photo_files = [f for f in os.listdir(photo_folder) if f.lower().endswith(photo_extensions)]


pd.DataFrame(photo_files, columns=["filename"]).to_csv("Subject_39_photo_files_names.csv", index=False)

# %%
#getting the list of suject 41 photos file names.
import os
import pandas as pd

# Set the folder path
photo_folder = "Subject41PhotosCGMacros" 

# List of common photo file extensions
photo_extensions = ('.jpg', '.jpeg', '.png', '.bmp', '.tiff', '.gif', '.webp')

# Get only photo files
photo_files = [f for f in os.listdir(photo_folder) if f.lower().endswith(photo_extensions)]


pd.DataFrame(photo_files, columns=["filename"]).to_csv("Subject_41_photo_files_names.csv", index=False)

# %%
#getting the list of suject 42 photos file names.
import os
import pandas as pd

# Set the folder path
photo_folder = "Subject42PhotosCGMacros" 

# List of common photo file extensions
photo_extensions = ('.jpg', '.jpeg', '.png', '.bmp', '.tiff', '.gif', '.webp')

# Get only photo files
photo_files = [f for f in os.listdir(photo_folder) if f.lower().endswith(photo_extensions)]


pd.DataFrame(photo_files, columns=["filename"]).to_csv("Subject_42_photo_files_names.csv", index=False)

# %%
#getting the list of suject 43 photos file names.
import os
import pandas as pd

# Set the folder path
photo_folder = "Subject43PhotosCGMacros" 

# List of common photo file extensions
photo_extensions = ('.jpg', '.jpeg', '.png', '.bmp', '.tiff', '.gif', '.webp')

# Get only photo files
photo_files = [f for f in os.listdir(photo_folder) if f.lower().endswith(photo_extensions)]


pd.DataFrame(photo_files, columns=["filename"]).to_csv("Subject_43_photo_files_names.csv", index=False)

# %%
#getting the list of suject 44 photos file names.
import os
import pandas as pd

# Set the folder path
photo_folder = "Subject44PhotosCGMacros" 

# List of common photo file extensions
photo_extensions = ('.jpg', '.jpeg', '.png', '.bmp', '.tiff', '.gif', '.webp')

# Get only photo files
photo_files = [f for f in os.listdir(photo_folder) if f.lower().endswith(photo_extensions)]


pd.DataFrame(photo_files, columns=["filename"]).to_csv("Subject_44_photo_files_names.csv", index=False)

# %%
#getting the list of suject 45 photos file names.
import os
import pandas as pd

# Set the folder path
photo_folder = "Subject45PhotosCGMacros" 

# List of common photo file extensions
photo_extensions = ('.jpg', '.jpeg', '.png', '.bmp', '.tiff', '.gif', '.webp')

# Get only photo files
photo_files = [f for f in os.listdir(photo_folder) if f.lower().endswith(photo_extensions)]


pd.DataFrame(photo_files, columns=["filename"]).to_csv("Subject_45_photo_files_names.csv", index=False)

# %%
#getting the list of suject 46 photos file names.
import os
import pandas as pd

# Set the folder path
photo_folder = "Subject46PhotosCGMacros" 

# List of common photo file extensions
photo_extensions = ('.jpg', '.jpeg', '.png', '.bmp', '.tiff', '.gif', '.webp')

# Get only photo files
photo_files = [f for f in os.listdir(photo_folder) if f.lower().endswith(photo_extensions)]


pd.DataFrame(photo_files, columns=["filename"]).to_csv("Subject_46_photo_files_names.csv", index=False)

# %%
#getting the list of suject 47 photos file names.
import os
import pandas as pd

# Set the folder path
photo_folder = "Subject47PhotosCGMacros" 

# List of common photo file extensions
photo_extensions = ('.jpg', '.jpeg', '.png', '.bmp', '.tiff', '.gif', '.webp')

# Get only photo files
photo_files = [f for f in os.listdir(photo_folder) if f.lower().endswith(photo_extensions)]


pd.DataFrame(photo_files, columns=["filename"]).to_csv("Subject_47_photo_files_names.csv", index=False)

# %%
#getting the list of suject 48 photos file names.
import os
import pandas as pd

# Set the folder path
photo_folder = "Subject48PhotosCGMacros" 

# List of common photo file extensions
photo_extensions = ('.jpg', '.jpeg', '.png', '.bmp', '.tiff', '.gif', '.webp')

# Get only photo files
photo_files = [f for f in os.listdir(photo_folder) if f.lower().endswith(photo_extensions)]


pd.DataFrame(photo_files, columns=["filename"]).to_csv("Subject_48_photo_files_names.csv", index=False)

# %%
#getting the list of suject 49 photos file names.
import os
import pandas as pd

# Set the folder path
photo_folder = "Subject49PhotosCGMacros" 

# List of common photo file extensions
photo_extensions = ('.jpg', '.jpeg', '.png', '.bmp', '.tiff', '.gif', '.webp')

# Get only photo files
photo_files = [f for f in os.listdir(photo_folder) if f.lower().endswith(photo_extensions)]


pd.DataFrame(photo_files, columns=["filename"]).to_csv("Subject_49_photo_files_names.csv", index=False)
